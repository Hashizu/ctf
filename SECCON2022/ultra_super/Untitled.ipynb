# %%
import pandas as pd

# %%
with open("./rule.yara", "r") as f:
  data = f.read()

# %%
rule_unit = """        $x1 = {e3 82 89 e3 81 9b e3 82 93 e9 9a 8e e6 ae b5}
        $x2 = {e3 82 ab e3 83 96 e3 83 88 e8 99 ab}
        $x3 = {e5 bb 83 e5 a2 9f e3 81 ae e8 a1 97}
        $x4 = {e3 82 a4 e3 83 81 e3 82 b8 e3 82 af e3 81 ae e3 82 bf e3 83 ab e3 83 88}
        $x5 = {e3 83 89 e3 83 ad e3 83 ad e3 83 bc e3 82 b5 e3 81 b8 e3 81 ae e9 81 93}
        $x6 = {e7 89 b9 e7 95 b0 e7 82 b9}
        $x7 = {e3 82 b8 e3 83 a7 e3 83 83 e3 83 88}
        $x8 = {e5 a4 a9 e4 bd bf}
        $x9 = {e7 b4 ab e9 99 bd e8 8a b1}
        $x10 = {e7 a7 98 e5 af 86 e3 81 ae e7 9a 87 e5 b8 9d}
        $x11 = {82 e7 82 b9 82 f1 8a 4b 92 69}
        $x12 = {83 4a 83 75 83 67 92 8e}
        $x13 = {94 70 9a d0 82 cc 8a 58}
        $x14 = {83 43 83 60 83 57 83 4e 82 cc 83 5e 83 8b 83 67}
        $x15 = {83 68 83 8d 83 8d 81 5b 83 54 82 d6 82 cc 93 b9}
        $x16 = {93 c1 88 d9 93 5f}
        $x17 = {83 57 83 87 83 62 83 67}
        $x18 = {93 56 8e 67}
        $x19 = {8e 87 97 7a 89 d4}
        $x20 = {94 e9 96 a7 82 cc 8d 63 92 e9}
        $x21 = {30 89 30 5b 30 93 96 8e 6b b5}
        $x22 = {30 4b 30 76}
        $x23 = {5e c3 58 9f 30 6e 88 57}
        $x24 = {30 a4 30 c1 30 b8 30 af 30 6e 30 bf 30 eb 30 c8}
        $x25 = {30 c9 30 ed 30 ed 30 fc 30 b5 30 78 30 6e 90 53}
        $x26 = {72 79 75 70 70 b9}
        $x27 = {30 b8 30 e7 30 c3 30 c8}
        $x28 = {59 29 4f 7f}
        $x29 = {7d 2b 96 7d 82 b1}
        $x30 = {79 d8 5b c6 30 6e 76 87 5e 1d}
        $x31 = {2b 4d 49 6b 2d 2b 4d 46 73 2d 2b 4d 4a 4d 2d 2b 6c 6f 34 2d}
        $x32 = {2b 4d 45 73 2d 2b 4d 48}
        $x33 = {2b 58 73 4d 2d 2b 57 4a 38 2d 2b 4d 47 34 2d 2b}
        $x34 = {2b 4d 4b 51 2d 2b 4d 4d 45 2d 2b 4d 4c 67 2d 2b 4d 4b 38 2d 2b 4d 47 34 2d 2b 4d 4c 38 2d 2b 4d}
        $x35 = {2b 4d 4d 6b 2d 2b 4d 4f 30 2d 2b 4d 4f 30 2d 2b 4d 50 77 2d 2b 4d 4c 55 2d 2b 4d 48 67 2d 2b 4d}
        $x36 = {2b 63 6e 6b 2d 2b 64 58 41 2d 2b 63}
        $x37 = {2b 4d 4c 67 2d 2b 4d 4f 63 2d 2b 4d 4d 4d 2d 2b}
        $x38 = {2b 57 53 6b 2d 2b 54 33}
        $x39 = {2b 66 53 73 2d 2b 6c 6e 30 2d 2b 67}
        $x40 = {2b 65 64 67 2d 2b 57 38 59 2d 2b 4d 47 34 2d 2b 64 6f 63 2d}"""

# %%
rule_unit_v = [x.split("{")[1][:-1] for x in rule_unit.replace(" ", "").split("\n")]

# %%
import chardet

# %%
encs = ['ascii',
 'big5',
 'big5hkscs',
 'cp037',
 'cp273',
 'cp424',
 'cp437',
 'cp500',
 'cp720',
 'cp737',
 'cp775',
 'cp850',
 'cp852',
 'cp855',
 'cp856',
 'cp857',
 'cp858',
 'cp860',
 'cp861',
 'cp862',
 'cp863',
 'cp864',
 'cp865',
 'cp866',
 'cp869',
 'cp874',
 'cp875',
 'cp932',
 'cp949',
 'cp950',
 'cp1006',
 'cp1026',
 'cp1125',
 'cp1140',
 'cp1250',
 'cp1251',
 'cp1252',
 'cp1253',
 'cp1254',
 'cp1255',
 'cp1256',
 'cp1257',
 'cp1258',
 'cp65001',
 'euc_jp',
 'euc_jis_2004',
 'euc_jisx0213',
 'euc_kr',
 'gb2312',
 'gbk',
 'gb18030',
 'hz',
 'iso2022_jp',
 'iso2022_jp_1',
 'iso2022_jp_2',
 'iso2022_jp_2004',
 'iso2022_jp_3',
 'iso2022_jp_ext',
 'iso2022_kr',
 'latin_1',
 'iso8859_2',
 'iso8859_3',
 'iso8859_4',
 'iso8859_5',
 'iso8859_6',
 'iso8859_7',
 'iso8859_8',
 'iso8859_9',
 'iso8859_10',
 'iso8859_11',
 'iso8859_13',
 'iso8859_14',
 'iso8859_15',
 'iso8859_16',
 'johab',
 'koi8_r',
 'koi8_t',
 'koi8_u',
 'kz1048',
 'mac_cyrillic',
 'mac_greek',
 'mac_iceland',
 'mac_latin2',
 'mac_roman',
 'mac_turkish',
 'ptcp154',
 'shift_jis',
 'shift_jis_2004',
 'shift_jisx0213',
 'utf_32',
 'utf_32_be',
 'utf_32_le',
 'utf_16',
 'utf_16_be',
 'utf_16_le',
 'utf_7',
 'utf_8',
 'utf_8_sig']

# %%
import binascii
#encs = ["utf-8",  "sjis", "utf_16_be", "utf_7"]
for i,c in enumerate(rule_unit_v):
    f=0

    for enc in encs:
        try:
            print(i+1,binascii.unhexlify(c).decode(enc))
            f = 1
            print(enc)
        except :
            continue
  #      if f==1:break
# Out:
# 1 TbiTaºTblZªþWÞ§
# cp037
# 1 TbiTaºTblZªþWÞ@
# cp273
# 1 πéëπü¢πéôΘÜÄµ«╡
# cp437
# 1 TbiTaºTblZªþWÞ§
# cp500
# 1 عéëعؤعéôلأµ«╡
# cp720
# 1 ήΓΚήΒδήΓΥώγΟόχ╡
# cp737
# 1 ŃéēŃüøŃéōķÜÄµ«Ą
# cp775
# 1 ÒéëÒüøÒéôÚÜÄµ«Á
# cp850
# 1 ŃéëŃüŤŃéôÚÜÄŠ«Á
# cp852
# 1 сѓЅсЂЏсѓЊжџјТ«х
# cp855
# 1 ÒéëÒüøÒéôÚÜÄµ«Á
# cp857
# 1 ÒéëÒüøÒéôÚÜÄµ«Á
# cp858
# 1 πéÊπü¢πéôΘÜÃµ«╡
# cp860
# 1 πéëπüøπéôΘÜÄµ«╡
# cp861
# 1 πגיπב¢πגףΘתמµ«╡
# cp862
# 1 πéëπü¢πéôΘÜÀµ«╡
# cp863
# 1 πéëπüøπéôΘÜÄµ«╡
# cp865
# 1 уВЙуБЫуВУщЪОцо╡
# cp866
# 1 TbiTaθTblZηεWρί
# cp875
# 1 繧峨○繧馴嚴谿ｵ
# cp932
# 1 ﻙﻙﻙﻠﮔ؟ﭖ
# cp1006
# 1 TbiTaºTblZª¦W@§
# cp1026
# 1 уВЙуБЫуВУщЪОцо╡
# cp1125
# 1 TbiTaºTblZªþWÞ§
# cp1140
# 1 г‚‰гЃ›г‚“йљЋж®µ
# cp1251
# 1 م‚‰مپ›م‚“éڑژو®µ
# cp1256
# 1 らせん階段
# cp65001
# 1 ãããéæ®µ
# latin_1
# 1 ăăăéćŽľ
# iso8859_2
# 1 ãããéæŽĩ
# iso8859_4
# 1 ууущцЎЕ
# iso8859_5
# 1 דדדיז®µ
# iso8859_8
# 1 ãããéæ®µ
# iso8859_9
# 1 ãããéæŪĩ
# iso8859_10
# 1 ใใใ้ๆฎต
# ...

# %%
import binascii
encs = ["utf-8",  "sjis", "utf_16_be", "utf7"]
for i,c in enumerate(rule_unit_v):
    enc = encs[(i)//10]
    try:
        print(i+1,binascii.unhexlify(c).decode(enc))
    except:
        print(i+1)
# Out:
# 1 らせん階段
# 2 カブト虫
# 3 廃墟の街
# 4 イチジクのタルト
# 5 ドロローサへの道
# 6 特異点
# 7 ジョット
# 8 天使
# 9 紫陽花
# 10 秘密の皇帝
# 11 らせん階段
# 12 カブト虫
# 13 廃墟の街
# 14 イチジクのタルト
# 15 ドロローサへの道
# 16 特異点
# 17 ジョット
# 18 天使
# 19 紫陽花
# 20 秘密の皇帝
# 21 らせん階段
# 22 かぶ
# 23 廃墟の街
# 24 イチジクのタルト
# 25 ドロローサへの道
# 26 特異点
# 27 ジョット
# 28 天使
# 29 紫陽花
# 30 秘密の皇帝
# 31 らせん階
# 32
# 33 廃墟の
# 34
# 35
# 36
# 37 ジョッ
# 38
# 39
# 40 秘密の皇

# %%
for i,c in zip(range(1,11),["a","b","c","d","e","f","g","h","i","j"]):
    print(f".replace('{i}','{c}')")
# Out:
# .replace('1','a')
# .replace('2','b')
# .replace('3','c')
# .replace('4','d')
# .replace('5','e')
# .replace('6','f')
# .replace('7','g')
# .replace('8','h')
# .replace('9','i')
# .replace('10','j')

# %%
q = "not (($x1 or $x6 or $x12 or not $x21 or $x32) and ($x3 or $x5 or not $x11 or $x24 or $x35) and (not $x3 or $x31 or $x40 or $x9 or $x27) and ($x4 or $x8 or $x10 or $x29 or $x40) and ($x4 or $x7 or $x11 or $x25 or not $x36) and ($x8 or $x14 or $x18 or $x21 or $x38) and ($x12 or $x15 or not $x20 or $x30 or $x35) and ($x19 or $x21 or not $x32 or $x33 or $x39) and ($x2 or $x37 or $x19 or not $x23) and (not $x5 or $x14 or $x23 or $x30) and (not $x5 or $x8 or $x18 or $x23) and ($x33 or $x22 or $x4 or $x38) and ($x2 or $x20 or $x39) and ($x3 or $x15 or not $x30) and ($x6 or not $x17 or $x30) and ($x8 or $x29 or not $x21) and (not $x16 or $x1 or $x29) and ($x20 or $x10 or not $x5) and (not $x13 or $x25) and ($x21 or $x28 or $x30) and not $x2 and $x3 and not $x7 and not $x10 and not $x11 and $x14 and not $x15 and not $x22 and $x26 and not $x27 and $x34 and $x36 and $x37 and not $x40)"
q.replace("or", "|").replace("not","~").replace("and", "&").replace("$","")#.replace('1','a').replace('2','b').replace('3','c').replace('4','d').replace('5','e').replace('6','f').replace('7','g').replace('8','h').replace('9','i').replace('0','j')
# Out:
# '~ ((x1 | x6 | x12 | ~ x21 | x32) & (x3 | x5 | ~ x11 | x24 | x35) & (~ x3 | x31 | x40 | x9 | x27) & (x4 | x8 | x10 | x29 | x40) & (x4 | x7 | x11 | x25 | ~ x36) & (x8 | x14 | x18 | x21 | x38) & (x12 | x15 | ~ x20 | x30 | x35) & (x19 | x21 | ~ x32 | x33 | x39) & (x2 | x37 | x19 | ~ x23) & (~ x5 | x14 | x23 | x30) & (~ x5 | x8 | x18 | x23) & (x33 | x22 | x4 | x38) & (x2 | x20 | x39) & (x3 | x15 | ~ x30) & (x6 | ~ x17 | x30) & (x8 | x29 | ~ x21) & (~ x16 | x1 | x29) & (x20 | x10 | ~ x5) & (~ x13 | x25) & (x21 | x28 | x30) & ~ x2 & x3 & ~ x7 & ~ x10 & ~ x11 & x14 & ~ x15 & ~ x22 & x26 & ~ x27 & x34 & x36 & x37 & ~ x40)'

# %%
q.replace("or", "|").replace("not","~").replace("and", "&").replace("$","")\
.replace('11','1').replace('12','2').replace('13','3').replace('14','4').replace('15','5').replace('16','6').replace('17','7').replace('18','8').replace('19','9').replace('20','10')\
.replace('21','1').replace('22','2').replace('23','3').replace('24','4').replace('25','5').replace('26','6').replace('27','7').replace('28','8').replace('29','9').replace('30','10')\
# Out:
# '~ ((x1 | x6 | x2 | ~ x1 | x32) & (x3 | x5 | ~ x1 | x4 | x35) & (~ x3 | x31 | x40 | x9 | x7) & (x4 | x8 | x10 | x9 | x40) & (x4 | x7 | x1 | x5 | ~ x36) & (x8 | x4 | x8 | x1 | x38) & (x2 | x5 | ~ x10 | x10 | x35) & (x9 | x1 | ~ x32 | x33 | x39) & (x2 | x37 | x9 | ~ x3) & (~ x5 | x4 | x3 | x10) & (~ x5 | x8 | x8 | x3) & (x33 | x2 | x4 | x38) & (x2 | x10 | x39) & (x3 | x5 | ~ x10) & (x6 | ~ x7 | x10) & (x8 | x9 | ~ x1) & (~ x6 | x1 | x9) & (x10 | x10 | ~ x5) & (~ x3 | x5) & (x1 | x8 | x10) & ~ x2 & x3 & ~ x7 & ~ x10 & ~ x1 & x4 & ~ x5 & ~ x2 & x6 & ~ x7 & x34 & x36 & x37 & ~ x40)'

# %%
# !pip install sympy
from sympy import Symbol, to_dnf, to_cnf

# %%
# for i in range(1,41):
#     print(f"x{i} = Symbol('x{i}')")
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
x11 = Symbol('x11')
x12 = Symbol('x12')
x13 = Symbol('x13')
x14 = Symbol('x14')
x15 = Symbol('x15')
x16 = Symbol('x16')
x17 = Symbol('x17')
x18 = Symbol('x18')
x19 = Symbol('x19')
x20 = Symbol('x20')
x21 = Symbol('x21')
x22 = Symbol('x22')
x23 = Symbol('x23')
x24 = Symbol('x24')
x25 = Symbol('x25')
x26 = Symbol('x26')
x27 = Symbol('x27')
x28 = Symbol('x28')
x29 = Symbol('x29')
x30 = Symbol('x30')
x31 = Symbol('x31')
x32 = Symbol('x32')
x33 = Symbol('x33')
x34 = Symbol('x34')
x35 = Symbol('x35')
x36 = Symbol('x36')
x37 = Symbol('x37')
x38 = Symbol('x38')
x39 = Symbol('x39')
x40 = Symbol('x40')

# %%
to_dnf(~ ((x1 | x6 | x12 | ~ x21 | x32) & (x3 | x5 | ~ x11 | x24 | x35) & (~ x3 | x31 | x40 | x9 | x27) & (x4 | x8 | x10 | x29 | x40) & (x4 | x7 | x11 | x25 | ~ x36) & (x8 | x14 | x18 | x21 | x38) & (x12 | x15 | ~ x20 | x30 | x35) & (x19 | x21 | ~ x32 | x33 | x39) & (x2 | x37 | x19 | ~ x23) & (~ x5 | x14 | x23 | x30) & (~ x5 | x8 | x18 | x23) & (x33 | x22 | x4 | x38) & (x2 | x20 | x39) & (x3 | x15 | ~ x30) & (x6 | ~ x17 | x30) & (x8 | x29 | ~ x21) & (~ x16 | x1 | x29) & (x20 | x10 | ~ x5) & (~ x13 | x25) & (x21 | x28 | x30) & ~ x2 & x3 & ~ x7 & ~ x10 & ~ x11 & x14 & ~ x15 & ~ x22 & x26 & ~ x27 & x34 & x36 & x37 & ~ x40),simplify=False,force=True)
# Out:
# x10 | x11 | x15 | x2 | x22 | x27 | x40 | x7 | ~x14 | ~x26 | ~x3 | ~x34 | ~x36 | ~x37 | (x13 & ~x25) | (x16 & ~x1 & ~x29) | (x17 & ~x30 & ~x6) | (x21 & ~x29 & ~x8) | (x30 & ~x15 & ~x3) | (x5 & ~x10 & ~x20) | (~x2 & ~x20 & ~x39) | (~x21 & ~x28 & ~x30) | (x23 & ~x19 & ~x2 & ~x37) | (x5 & ~x14 & ~x23 & ~x30) | (x5 & ~x18 & ~x23 & ~x8) | (~x22 & ~x33 & ~x38 & ~x4) | (x11 & ~x24 & ~x3 & ~x35 & ~x5) | (x20 & ~x12 & ~x15 & ~x30 & ~x35) | (x21 & ~x1 & ~x12 & ~x32 & ~x6) | (x3 & ~x27 & ~x31 & ~x40 & ~x9) | (x32 & ~x19 & ~x21 & ~x33 & ~x39) | (x36 & ~x11 & ~x25 & ~x4 & ~x7) | (~x10 & ~x29 & ~x4 & ~x40 & ~x8) | (~x14 & ~x18 & ~x21 & ~x38 & ~x8)

# %%
to_dnf(~ ((x1 | x6 | x2 | ~ x1 | x32) & (x3 | x5 | ~ x1 | x4 | x35) & (~ x3 | x31 | x40 | x9 | x7) & (x4 | x8 | x10 | x9 | x40) & (x4 | x7 | x1 | x5 | ~ x36) & (x8 | x4 | x8 | x1 | x38) & (x2 | x5 | ~ x10 | x10 | x35) & (x9 | x1 | ~ x32 | x33 | x39) & (x2 | x37 | x9 | ~ x3) & (~ x5 | x4 | x3 | x10) & (~ x5 | x8 | x8 | x3) & (x33 | x2 | x4 | x38) & (x2 | x10 | x39) & (x3 | x5 | ~ x10) & (x6 | ~ x7 | x10) & (x8 | x9 | ~ x1) & (~ x6 | x1 | x9) & (x10 | x10 | ~ x5) & (~ x3 | x5) & (x1 | x8 | x10) & ~ x2 & x3 & ~ x7 & ~ x10 & ~ x1 & x4 & ~ x5 & ~ x2 & x6 & ~ x7 & x34 & x36 & x37 & ~ x40),simplify=True,force=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e35e50e16e0d> in <module>
# ----> 1 to_dnf(~ ((x1 | x6 | x2 | ~ x1 | x32) & (x3 | x5 | ~ x1 | x4 | x35) & (~ x3 | x31 | x40 | x9 | x7) & (x4 | x8 | x10 | x9 | x40) & (x4 | x7 | x1 | x5 | ~ x36) & (x8 | x4 | x8 | x1 | x38) & (x2 | x5 | ~ x10 | x10 | x35) & (x9 | x1 | ~ x32 | x33 | x39) & (x2 | x37 | x9 | ~ x3) & (~ x5 | x4 | x3 | x10) & (~ x5 | x8 | x8 | x3) & (x33 | x2 | x4 | x38) & (x2 | x10 | x39) & (x3 | x5 | ~ x10) & (x6 | ~ x7 | x10) & (x8 | x9 | ~ x1) & (~ x6 | x1 | x9) & (x10 | x10 | ~ x5) & (~ x3 | x5) & (x1 | x8 | x10) & ~ x2 & x3 & ~ x7 & ~ x10 & ~ x1 & x4 & ~ x5 & ~ x2 & x6 & ~ x7 & x34 & x36 & x37 & ~ x40),simplify=True,force=True)
#
# ~\Anaconda3\envs\python3.6\lib\site-packages\sympy\logic\boolalg.py in to_dnf(expr, simplify, force)
# ...

# %%
res = to_dnf(~ ((x1 | x6 | x12 | ~ x21 | x32) & (x3 | x5 | ~ x11 | x24 | x35) & (~ x3 | x31 | x40 | x9 | x27) & (x4 | x8 | x10 | x29 | x40) & (x4 | x7 | x11 | x25 | ~ x36) & (x8 | x14 | x18 | x21 | x38) & (x12 | x15 | ~ x20 | x30 | x35) & (x19 | x21 | ~ x32 | x33 | x39) & (x2 | x37 | x19 | ~ x23) & (~ x5 | x14 | x23 | x30) & (~ x5 | x8 | x18 | x23) & (x33 | x22 | x4 | x38) & (x2 | x20 | x39) & (x3 | x15 | ~ x30) & (x6 | ~ x17 | x30) & (x8 | x29 | ~ x21) & (~ x16 | x1 | x29) & (x20 | x10 | ~ x5) & (~ x13 | x25) & (x21 | x28 | x30) & ~ x2 & x3 & ~ x7 & ~ x10 & ~ x11 & x14 & ~ x15 & ~ x22 & x26 & ~ x27 & x34 & x36 & x37 & ~ x40),simplify=True,force=True)
res
